# %%
import tkinter as tk
from tkinter import *
import matplotlib
matplotlib.use("TkAgg")
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
from matplotlib.figure import Figure
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.animation import FuncAnimation
from matplotlib.animation import ArtistAnimation
import matplotlib.pyplot as plt
import numpy as np

#Setting constants 
ep_0 = 8.8541878*(10**(-12))
mew_0 = 4*(np.pi)*(10**(-7))
c0 = 299792458

# %%
class Grid:
    
    def __init__(self, grid_res = 0.1, t_steps = 500, x_steps = 200, y_steps = 200):
        
        self.ds = grid_res      #Grid Resolution (size of space step)
        self.x_steps = x_steps  #No. of point on x axis
        self.y_steps = y_steps  #No. of point on y axis
        
        self.x_len  = (self.x_steps-1)*self.ds
        self.x_axis = np.linspace(0, self.x_len, self.x_steps) 
        
        self.y_len  = (self.y_steps-1)*self.ds
        self.y_axis = np.linspace(0, self.y_len, self.y_steps)
        
        self.dt = self.ds/(np.sqrt(2.0)*c0) #dt is chosen using courant stability condition
        
        self.t_steps = t_steps              #No. of steps in simulation
        self.time_period = (self.t_steps-1)*self.dt
        self.t_axis = np.linspace(0, self.time_period, self.t_steps)
        
        self.mew_r = np.ones((self.x_steps,self.y_steps)) #relative permeability at every point in the grid; set to 1 in constructor
        self.ep_r = np.ones((self.x_steps,self.y_steps))  #relative permittivity at every point in the grid; set to 1 in constructor
        self.σ = np.zeros((self.x_steps,self.y_steps)) #electriclal conductivity at every point in the grid; set to 0 in constructor
        self.n = np.sqrt(self.mew_r*self.ep_r)  # refractive index at every point in the grid
        
        self.Es = np.zeros((self.t_steps, self.x_steps, self.y_steps))
    
    def set_environment_parameters(self, mew_r = 1.0, ep_r =1.0, σ = 0.0, portion = 'half Y'):
        if portion == 'whole grid':
            self.mew_r[:,:] = mew_r  # relative permeability in whole grid
            self.ep_r[:,:] = ep_r   # relative permittivity in whole grid
            self.σ[:,:] = σ  # electrical conductivity in whole grid
            self.n = np.sqrt(self.mew_r*self.ep_r)
        
        elif portion == 'half Y':
            self.mew_r[:,self.y_steps//2:-4] = mew_r  # relative permeability in part of the grid
            self.ep_r[:,self.y_steps//2:-4]  = ep_r   # relative permittivity in part of the grid
            self.σ[:,self.y_steps//2:-4] = σ  # electrical conductivity in part of the grid
            self.n = np.sqrt(self.mew_r*self.ep_r)
        
        elif portion == 'half X':
            self.mew_r[4:self.x_steps//2,:] = mew_r  # relative permeability in part of the grid
            self.ep_r[4:self.x_steps//2,:]  = ep_r   # relative permittivity in part of the grid
            self.σ[4:self.x_steps//2,:] = σ  # electrical conductivity in part of the grid
            self.n = np.sqrt(self.mew_r*self.ep_r)
         
        return None
    
    def set_lossy_border(self, upto_pos = 30, max = 10**-2):
        """Keep EM waves from reaching the boundary 
        
        -Make the borders of the simulation grid extremely lossy so the EM wave does not
           reach the boundary
           
        -The electrical conductivity is increased progressively as we get closer to the border to avoid
           reflection of the waves into the simulation region
        """
        self.bndry_sz = upto_pos
        grow = np.linspace(0, 1, num= upto_pos, endpoint=True)
        grow = grow**2
        for y in range(0, self.Es.shape[2], 1):                  
            self.σ[:upto_pos,y] += max*grow[::-1] 
            self.σ[-upto_pos:,y] += grow*max
        for x in range(0, self.Es.shape[1], 1):
            self.σ[x,:upto_pos] += max*grow[::-1] 
            self.σ[x,-upto_pos:] += grow*max
            
    def set_source(self, x_pos, y_pos, kind = 'Point Impusle', theta = 0):
   
        if kind == 'Point Impulse':
            #Gaussian source (impulse)
            #Source Parameters
            tau = 10*self.dt
            t0  = 10*tau
            
            #Generating Electric Field source over time
            Esrc = np.exp(-((self.t_axis-t0)/tau)**2) 
            self.Es[:, x_pos, y_pos] += Esrc[:]
            
        elif kind == 'Plane Impulse':
            #Gaussian source (impulse)
            #Source Parameters
            tau = 10*self.dt
            t0  = 10*tau
            #Generating Electric Field source over time
            for x in range(0, self.Es.shape[1], 1):    
                self.Es[:, x, y_pos] += 100*np.exp(-((self.t_axis-t0)/tau)**2)/self.x_axis.size
        
        elif kind == 'Point Sine':
            T = 40*self.dt
            Esrc = np.sin(2*np.pi*self.t_axis/T)
            self.Es[:, x_pos, y_pos] += Esrc[:]
        
        elif kind == 'Plane Sine Wave':
            T = 20*self.dt
            Esrc = np.sin(2*np.pi*self.t_axis/T)/self.x_axis.size
            for t in range(0, self.Es.shape[0], 1):
                self.Es[t][:,y_pos] += Esrc[t]
                
        elif kind == 'Dir Plane Sine Wave':
            m = -np.tan(theta)  #thetha is the angle made with the vertical by the wavevector
            T = 40*self.dt   # Time period of source
            Esrc = np.sin(2*np.pi*self.t_axis/T)/self.x_axis.size # Sine source
            
            for t in range(0, self.Es.shape[0], 1):
                for x in range(0, self.Es.shape[1], 1):
                    y = int(m*(x-x_pos)) + y_pos
                    if  y>= 0 and y < self.Es.shape[2]:
                        #The gau term ensures limited spread of the plane wave
                        gau = np.exp( -( ((self.x_axis[x]-self.x_axis[x_pos])/3)**2 + ((self.y_axis[y]-self.y_axis[y_pos])/3)**2 ) )
                        #Registering the source
                        self.Es[t][x,y] += 100*gau*Esrc[t]
        
        return None

import copy

def FDTD(Grid):
    dt = Grid.dt
    ds = Grid.ds
    
    mew_r = Grid.mew_r
    ep_r  = Grid.ep_r
    σ     = Grid.σ
    
    #Update Coefficients for fdtd (chosen basedon Maxwell's equations with normalized Electric and Magnetic field values)
    mH = (-dt*c0/(mew_r*ds))

    mE1 = (2*ep_0*ep_r - σ*dt)/(2*ep_0*ep_r + σ*dt)
    mE2 = 2*ep_0*c0*dt/(ds*(2*ep_0*ep_r + dt*σ))
    
    HxOverTime = np.zeros((Grid.t_steps, Grid.x_steps, Grid.y_steps)) 
    HyOverTime = np.zeros((Grid.t_steps, Grid.x_steps, Grid.y_steps)) 
    EzOverTime = np.zeros((Grid.t_steps, Grid.x_steps, Grid.y_steps)) 

    for t in range(1, Grid.t_steps, 1):
        
        Hx = HxOverTime[t-1][:, :]
        Hy = HyOverTime[t-1][:, :]
        Ez = EzOverTime[t-1][:, :]

        Hx[:,:-1] += mH[:,:-1]*(Ez[:,1:]-Ez[:,:-1])  #Change in Ez over y
        Hx[:,-1] += mH[:,-1]*(0-Ez[:,-1]) #Boundary Condition (y high)

        HxOverTime[t][:,:] += Hx[:,:]

        Hy[:-1,:] -= mH[:-1,:]*(Ez[1:,:]-Ez[:-1,:])  #Change on Ez over x
        Hy[-1,:] -= mH[-1,:]*(Ez[0,:]-Ez[-1,:])  #Boundary Condition (x high)

        HyOverTime[t][:,:] += Hy[:,:]

        CHz = np.zeros(Ez.shape)  #z component of curl of H
        CHz[1:,:] += (Hy[1:,:]-Hy[:-1,:])  #Change in Hy over x
        CHz[0,:] += (Hy[0,:]- Hy[-1,:])  #Boundary Condition (x low)
        CHz[:,1:] -= (Hx[:,1:]-Hx[:,:-1])  #Change in Hx over y
        CHz[:,0] -= (Hx[:,0]-0)  #Boundary Condition (y low)
        CHz[0,0] += Hy[0,0] - Hx[0,0]  #Boundary Condition (origin)
        Ez = mE1[:,:]*Ez + mE2[:,:]*CHz[:,:]

        Ez += Grid.Es[t]  #injecting source at a point in the grid

        EzOverTime[t][:,:] += Ez[:,:]
    
    return HxOverTime, HyOverTime, EzOverTime

def reflectance_t0_ep_r(R):
    if R == 1:
        ep_r = 10**20   #arbitrarily large number to stand in for infinity
    else:
        ep_r = ((1+np.sqrt(R))/(1-np.sqrt(R)))**2
    return ep_r

# This formula only applies when incidence is perpendicular
def perp_ref_to_ep_r(R):
    if R == 1:
        ep_r = 10**20   #arbitrarily large number to stand in for infinity
    else:
        ep_r = ((1+np.sqrt(R))/(1-np.sqrt(R)))**2
    return ep_r

def perp_loss_to_σ(L, dt, ds):    # WORK IN PROGRESS
    return ep_0*L/(105*100*dt*ds)


R = 0.05       #Ratio of Energy Reflected
L = 0.5         #Loss
T = 1.0 -R-L  #Ratio of Energy Tranmitted

# %%
EMGrid = Grid(t_steps = 500, x_steps = 400, y_steps = 300)  # Creating a grid to simulate over

EMGrid.set_lossy_border(40, 50*10**-(3)) # Making sure EM waves don't get to the coundary
EMGrid.set_environment_parameters(mew_r = 1.0, ep_r = perp_ref_to_ep_r(R), σ = perp_loss_to_σ(L, EMGrid.dt, EMGrid.ds), portion = 'half Y')  #Setting half the grid to have diff. dielectric constant 

EMGrid.set_source(x_pos = EMGrid.x_steps//3, y_pos = EMGrid.y_steps//3, kind = 'Dir Plane Sine Wave', theta = 0)  # Adding directional wave source 

HxOverTime, HyOverTime, EzOverTime = FDTD(EMGrid)  # Running simulation

o2 = Figure(figsize=(6,4), dpi=80)
ax2 = o2.add_subplot(111, xlim=(0, EMGrid.x_len), ylim = (-0.05,0.05))
for i in range(0, EMGrid.y_steps, 1):
    if EMGrid.n[100,i] == 1.0:
        ax2.axvspan(i*EMGrid.ds, (i+1)*EMGrid.ds, facecolor='w')
    else:
        ax2.axvspan(i*EMGrid.ds, (i+1)*EMGrid.ds, facecolor='silver')

line, = ax2.plot([], [], lw=2)

def init():
    line.set_data([], [])
    return line,

#The E field over y axis is plotted every 10th time step
def animate(t):
    x = EMGrid.y_axis
    y = EzOverTime[10*t, EMGrid.x_steps//2]
    ax2.set_title("Step " + str(10*t+1) + " of " + str(EMGrid.t_steps)+ " : time = " + str(10*t*EMGrid.dt))
    line.set_data(x, y)
    return line,

        
ax2.set_xlabel('y axis')
ax2.set_ylabel('Electric Field')
# Out:
# Text(0, 0.5, 'Electric Field')

# %%
class Sphere():
    def __init__(self, *args, **kwargs):
        self.fig = Figure(figsize=(4,4), dpi=80)
        self.ax = self.fig.add_subplot(111, projection='3d')

    def draw(self, theta_num, phi_num, initview, pos_arr):
        theta_array, phi_array = np.mgrid[0.0:np.pi:theta_num*1j, 0.0:2.0*np.pi:phi_num*1j]
        x_array = np.sin(theta_array) * np.cos(phi_array)
        y_array = np.sin(theta_array) * np.sin(phi_array)
        z_array = np.cos(theta_array)
        meridian_y = np.sin(np.linspace(0, np.pi, theta_num))
        meridian_z = np.cos(np.linspace(0, np.pi, theta_num))
        meridian_x = [0]*len(meridian_y)
        self.ax.clear()
        self.ax.plot3D(meridian_x, meridian_y, meridian_z) # a reference line for rotation
        self.ax.plot_surface(x_array, y_array, z_array, alpha=0.2)
        self.ax.set_xlim([-1,1])
        self.ax.set_ylim([-1,1])
        self.ax.set_zlim([-1,1])
        self.ax.set_xlabel("Reflect amplitude")
        self.ax.set_ylabel("Transmission amplitude")
        self.ax.set_zlabel("Loss amplitude")

        self.ax.scatter(x_array, y_array, z_array, s=2)
        self.ax.scatter(pos_arr[0],pos_arr[1], pos_arr[2],s=50,color='r')
        self.ax.view_init(initview[0], initview[1])
        
class Universe(tk.Tk):
    def __init__(self, *args, **kwargs):
        tk.Tk.__init__(self, *args, **kwargs)
        tk.Tk.wm_title(self, "Welcome to Graphics")
        tk.Tk.config(self, bg="skyblue")
        
        # Create left and right frames
        left_frame = Frame(self, bg='grey')
        left_frame.pack(side='left', fill='both', padx=10, pady=5, expand=True)

        right_frame = Frame(self, bg='grey')
        right_frame.pack(side='right', fill='both', padx=10, pady=5, expand=True)
        
        #constants
        constants = Frame(left_frame, bg='lightgrey')
        constants.pack(side='top', fill='both', padx=5, pady=5, expand=True)
        words = Frame(constants, bg='lightgrey')
        words.pack(side='left', fill='both', padx=5, pady=5, expand=True)
        inputs = Frame(constants, bg='lightgrey')
        inputs.pack(side='right', fill='both', padx=5, pady=5, expand=True)

        #number of points
        points = Frame(left_frame, bg='lightgrey')
        points.pack(side='top', fill='both', padx=5, pady=5, expand=True)
        question = Frame(points, width=90, height=185, bg='lightgrey')
        question.pack(side='left', fill='both', padx=5, pady=5, expand=True)
        numpts = Frame(points, width=90, height=185, bg='lightgrey')
        numpts.pack(side='right', fill='both', padx=5, pady=5, expand=True)
        
        #grid settings
        grid = Frame(left_frame, bg='lightgrey')
        grid.pack(side='top', fill='both', padx=5, pady=5, expand=True)
        question1 = Frame(grid, bg='lightgrey')
        question1.pack(side='left', fill='both', padx=5, pady=5, expand=True)
        setting = Frame(grid, bg='lightgrey')
        setting.pack(side='right', fill='both', padx=5, pady=5, expand=True)
        
        #choices
        choices = Frame(left_frame, bg='lightgrey')
        choices.pack(side='top', fill='both', padx=5, pady=5, expand=True)
        method = Frame(choices, bg='lightgrey')
        method.pack(side='left', fill='both', padx=5, pady=5, expand=True)
        source = Frame(choices, bg='lightgrey')
        source.pack(side='right', fill='both', padx=5, pady=5, expand=True)

        #graphs
        graph1 = Frame(right_frame, bg='lightgrey')
        graph1.pack(side='top', fill='both', padx=5, pady=5, expand=True)
        slider = Frame(graph1, bg='lightgrey')
        slider.pack(side='left', fill='both', padx=5, pady=5, expand=True)
        sph = Frame(graph1, bg='lightgrey')
        sph.pack(side='right', fill='both', padx=5, pady=5, expand=True)
        graph2 = Frame(right_frame, bg='lightgrey')
        graph2.pack(side='top', fill='both', padx=5, pady=5, expand=True)
        Label(graph2, text="Ez over Y").pack(side='top', padx=5, pady=5)


        #user defined constants
        tk.Label(words, 
                 text="Electrical Conductivity").pack(padx=3, pady=1)
        tk.Label(words, 
                 text="Relative Permittivity").pack(padx=3, pady=1)
        tk.Label(words, 
                 text="Relative Permeability").pack(padx=3, pady=1)

        eleccond = tk.Entry(inputs)
        relpt = tk.Entry(inputs)
        relpm = tk.Entry(inputs)
        eleccond.pack(padx=3, pady=1)
        relpt.pack(padx=3, pady=1)
        relpm.pack(padx=3, pady=1)
        
        #number of data points
        tk.Label(question, 
                 text="How many data points for polar(theta) angle?").pack()
        tk.Label(question, 
                  text="How many data points for azimuthal(phi) angle?").pack()
        
        theta_num = tk.IntVar(value=20)
        phi_num = tk.IntVar(value=20)   

        get_theta_num = tk.Entry(numpts, textvariable=str(theta_num))
        get_phi_num = tk.Entry(numpts, textvariable=str(phi_num))
        
        get_theta_num.pack()
        get_phi_num.pack()
        
        #grid
        tk.Label(question1, 
                 text="What's the grid resolution? default: 0.1").pack()
        tk.Label(question1, 
                 text="What's the number of steps? default: 300").pack()
        tk.Label(question1, 
                 text="What's the number of points on x axis? default: 200").pack()
        tk.Label(question1, 
                 text="What's the number of points on y axis? default: 200").pack()
        
        res = tk.DoubleVar(value=0.1)
        t_steps = tk.IntVar(value=300)   
        x_steps = tk.IntVar(value=200)   
        y_steps = tk.IntVar(value=200)   
        
        get_res = tk.Entry(setting, textvariable=res)
        get_t_steps = tk.Entry(setting, textvariable=t_steps)
        get_x_steps = tk.Entry(setting, textvariable=x_steps)
        get_y_steps = tk.Entry(setting, textvariable=y_steps)
        
        get_res.pack(pady=3)
        get_t_steps.pack()
        get_x_steps.pack()
        get_y_steps.pack()

        #sphere
        o1 = Sphere()
        o1.draw(int(theta_num.get()), int(phi_num.get()), [45,45], [0,0,0])
        def return_method(*args):
            nonlocal o1, canvas
            canvas.get_tk_widget().delete("all")
            o1.draw(int(theta_num.get()), int(phi_num.get()), [20,45], point_pos_arr)
            canvas = FigureCanvasTkAgg(o1.fig, sph)
            canvas.get_tk_widget().pack()
            canvas._tkcanvas.pack()

        get_theta_num.bind('<Return>', return_method)
        get_phi_num.bind('<Return>', return_method) 
        
        #User defined graph portion and EM wave source
        tk.Label(method, 
                 text="Method").pack(padx=3, pady=1)
        v = StringVar()
        v.set("Whole grid")
        Radiobutton(method, text="Whole grid", variable=v, value="whole grid").pack(padx=3, pady=1)
        Radiobutton(method, text="Half Y", variable=v, value="Half X").pack(padx=3, pady=1)
        Radiobutton(method, text="Half X", variable=v, value="Half Y").pack(padx=3, pady=1)

        tk.Label(source, 
                 text="EM Wave Source").pack(padx=3, pady=1)
        get_kind = StringVar()
        get_kind.set('Point Impulse')
        Radiobutton(source, text='Point Impulse', variable=get_kind, value='Point Impulse').pack(padx=3, pady=1)
        Radiobutton(source, text='Plane Impulse', variable=get_kind, value='Plane Impulse').pack(padx=3, pady=1)
        Radiobutton(source, text='Point Sine', variable=get_kind, value='Point Sine').pack(padx=3, pady=1)
        Radiobutton(source, text='Plane Sine Wave', variable=get_kind, value='Plane Sine Wave').pack(padx=3, pady=1)
        Radiobutton(source, text='Dir Plane Sine Wave', variable=get_kind, value='Dir Plane Sine Wave').pack(padx=3, pady=1)

        # the sliders are from Graphics, Veronica
        self.ref_var = tk.IntVar()
        self.ref = tk.Scale(slider, from_=0, to=1, orient=tk.HORIZONTAL, variable=self.ref_var, label='Reflectivity', resolution=0.01, sliderlength=10, length=150)
        self.ref.pack()
        self.ref.set(0.4)
        
        self.trans_var = tk.IntVar()
        self.trans = tk.Scale(slider, from_=0, to=1, orient=tk.HORIZONTAL, variable=self.trans_var, label='Transmissivity', resolution=0.01, sliderlength=10, length=150)
        self.trans.pack()
        self.trans.set(0.6)
        
        self.loss = tk.Scale(slider, from_=0, to=1, orient=tk.HORIZONTAL, label='Loss', resolution=0.01, state='disabled', sliderlength=10, length=150)
        self.loss.pack()
        def trace_method(*args):
            self.loss.config(state="normal")
            self.loss.set(1 - self.ref.get() - self.trans.get())
            self.loss.config(state="disabled")
            self.trans.config(to=1-self.ref.get()) # update to change the maximum of transmission value 
            
            nonlocal point_pos_arr, o1, canvas
            point_pos_arr = [round(x,3) for x in [np.sqrt(self.ref.get()), np.sqrt(self.trans.get()), np.sqrt(self.loss.get())]]   
            point_pos.config(text="The point position on RTL sphere is at" + str(point_pos_arr))
            o1.draw(int(theta_num.get()), int(phi_num.get()), [20,45], point_pos_arr)
        
        def set_values(*args):
            global R, T, L, o2, EMGrid, HxOverTime, HyOverTime, EzOverTime
            R = self.ref.get()
            T = self.trans.get()
            L = 1 - R - T
            set_values.config(text= "The point position on RTL sphere is at"+str([round(x, 3) for x in [R, T, L]]))
            EMGrid.set_environment_parameters(mew_r = 1.0, ep_r = reflectance_t0_ep_r(R), σ = 0*10**(-3), portion = 'half Y')
            HxOverTime, HyOverTime, EzOverTime = FDTD(EMGrid)
            
        self.ref_var.trace("w", trace_method)
        self.trans_var.trace("w", trace_method)
        tk.Button(slider, text='Set R, T, L values', command=set_values).pack()
        
        point_pos_arr = [np.sqrt(self.ref.get()), np.sqrt(self.trans.get()), np.sqrt(self.loss.get())]
        point_pos = tk.Label(slider, text = "The point position on RTL sphere is at\n" + str(point_pos_arr))
        point_pos.pack()
        
        set_values = tk.Label(slider, text="The set values for R, T, L is\n"+ str([self.ref.get(), self.trans.get(), self.loss.get()])).pack()

       
        def em_params_return(*args):
            global EMGrid, HxOverTime, HyOverTime, EzOverTime
            EMGrid = Grid(grid_res=float(get_res.get()), t_steps = int(get_t_steps.get()), x_steps=int(get_x_steps.get()), y_steps=int(get_y_steps.get()))
            EMGrid.set_environment_parameters(mew_r = 1.0, ep_r = reflectance_t0_ep_r(R), σ = 0*10**(-3), portion = 'half Y')
            EMGrid.set_source(x_pos = EMGrid.x_steps//2, y_pos = EMGrid.y_steps//3, kind = str(get_kind.get()))
            HxOverTime, HyOverTime, EzOverTime = FDTD(EMGrid)
            
            
        get_res.bind('<Return>', em_params_return)
        get_t_steps.bind('<Return>', em_params_return)
        get_x_steps.bind('<Return>', em_params_return)
        get_y_steps.bind('<Return>', em_params_return)
        #get_kind.bind('<Return>', em_params_return)

        canvas = FigureCanvasTkAgg(o1.fig, graph1)
        canvas.get_tk_widget().pack()
        canvas._tkcanvas.pack()

        canvasEm = FigureCanvasTkAgg(o2, graph2)
        canvasEm.draw()
        canvasEm.get_tk_widget().pack()
        canvasEm._tkcanvas.pack()
        
        def store_values():
            mew_r = relpm.get()
            σ = eleccond.get()
            ep_r = relpt.get()
            portion = v.get()
            kind = get_kind.get()
            R = ref.get()
            L = loss.get()
            T = trans.get()
    
        tk.Button(left_frame, text='Enter', command=store_values).pack()

app = Universe()
anim = FuncAnimation(o2, animate, init_func=init,
                               frames=EMGrid.t_steps//10, interval=100)
app.mainloop()
